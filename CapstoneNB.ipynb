# %% [markdown]
# <h1> Capstone Project NoteBook<h1>
# <h4>I will be using this NB for my Capstone Project to perform various DS techniques in order determine insights from the Battle of Neighborhoods<h4>

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
